# %%
# --- Lab 3.2 Part 1: Countdown Timer ---
start = int(input("Enter starting number for countdown: "))
while start >= 0:
    print(start)
    start -= 1

print("Blast off!")
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
# Blast off!

# %%
secret_number = 67
attempt = 1
max_attempts = 5

while attempt <= max_attempts:
    guess = int(input(f"Attempt {attempt}/{max_attempts} - Guess the number: "))

    if guess < secret_number:
        print(f"{guess} is too low! Try again.")
    elif guess > secret_number:
        print(f"{guess} is too high! Try again.")
    else:
        print("Congratulations! You guessed it!")
        break

    attempt += 1

else:
    print("Game Over! You've used all 5 attempts.")
# Out:
# 21 is too low! Try again.
# 22 is too low! Try again.
# 35 is too low! Try again.
# 40 is too low! Try again.
# 60 is too low! Try again.
# Game Over! You've used all 5 attempts.
